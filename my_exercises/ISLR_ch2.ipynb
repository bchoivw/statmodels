# %%
# Brian's ISLR exercise 2.8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('hwdata\College.csv')

# %%
df
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
df.rename(columns={'Unnamed: 0':'College Name'},inplace=True)

# %%
df.set_index('College Name',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
# Private        777 non-null object
# Apps           777 non-null int64
# Accept         777 non-null int64
# Enroll         777 non-null int64
# Top10perc      777 non-null int64
# Top25perc      777 non-null int64
# F.Undergrad    777 non-null int64
# P.Undergrad    777 non-null int64
# Outstate       777 non-null int64
# Room.Board     777 non-null int64
# Books          777 non-null int64
# Personal       777 non-null int64
# PhD            777 non-null int64
# Terminal       777 non-null int64
# S.F.Ratio      777 non-null float64
# perc.alumni    777 non-null int64
# Expend         777 non-null int64
# Grad.Rate      777 non-null int64
# dtypes: float64(1), int64(16), object(1)
# memory usage: 115.3+ KB

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
sns.pairplot(df.iloc[:,:10])

# %%
sns.boxplot(x="Private",y="Outstate",data=df)
plt.title("Out of State Tuition")
# Out:
# Text(0.5, 1.0, 'Out of State Tuition')

# %%
df.head(4)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College Name
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College Name
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# College Name
# Abilene Christian University        3300    450      2200   70        78
# ...

# %%
df['Elite'] = 'No'

# %%
# df[df['Top10perc']>50]['Elite'] = 'Yes'
df.loc[df['Top10perc']>50,'Elite'] = 'Yes'

# %%
print(list(df[df['Elite']=='Yes'].index))
# Out:
# ['Agnes Scott College', 'Amherst College', 'Barnard College', 'Birmingham-Southern College', 'Bowdoin College', 'Brown University', 'Bryn Mawr College', 'Carleton College', 'Carnegie Mellon University', 'Case Western Reserve University', 'Centre College', 'Claremont McKenna College', 'Colby College', 'College of the Holy Cross', 'College of William and Mary', 'Colorado College', 'Columbia University', 'Dartmouth College', 'Davidson College', 'Drew University', 'Duke University', 'Emory University', 'Fresno Pacific College', 'Furman University', 'Georgetown University', 'Georgia Institute of Technology', 'Grinnell College', 'Grove City College', 'Harvard University', 'Harvey Mudd College', 'Hendrix College', 'Illinois Wesleyan University', 'Johns Hopkins University', 'Macalester College', 'Massachusetts Institute of Technology', 'New York University', 'Niagara University', 'Northwestern University', 'Occidental College', 'Oglethorpe University', 'Pepperdine University', 'Polytechnic U
# ...

# %%
sns.boxplot(x="Elite",y="Outstate",data=df)
plt.title("Elite vs Non-Elite Tuition")
# Out:
# Text(0.5, 1.0, 'Elite vs Non-Elite Tuition')

# %%
df['Outstate'].plot.hist()

# %%
df['Outstate'].plot.hist(bins=6)

# %%
df[['Outstate','Enroll']].plot.hist()

# %%
df[['Outstate','Enroll']].hist();

# %%
# f, ax = plt.subplots(figsize=(20,20))
df[['Outstate','Enroll','S.F.Ratio','Grad.Rate']].hist(figsize=(20,20));

# %%
# Brian's ISLR exercise 2.9

# %%
auto = pd.read_csv('hwdata\Auto.csv')

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
# mpg             397 non-null float64
# cylinders       397 non-null int64
# displacement    397 non-null float64
# horsepower      397 non-null object
# weight          397 non-null int64
# acceleration    397 non-null float64
# year            397 non-null int64
# origin          397 non-null int64
# name            397 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
auto = pd.read_csv('hwdata\Auto 2.csv',index_col='Unnamed: 0')

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 1 to 397
# Data columns (total 9 columns):
# mpg             392 non-null float64
# cylinders       392 non-null int64
# displacement    392 non-null float64
# horsepower      392 non-null int64
# weight          392 non-null int64
# acceleration    392 non-null float64
# year            392 non-null int64
# origin          392 non-null int64
# name            392 non-null object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB

# %%
auto.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1  18.0          8         307.0         130    3504          12.0    70
# 2  15.0          8         350.0         165    3693          11.5    70
# 3  18.0          8         318.0         150    3436          11.0    70
#
#    origin                       name
# 1       1  chevrolet chevelle malibu
# 2       1          buick skylark 320
# 3       1         plymouth satellite

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
# origin could be categorical

# %%
auto.std()
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# origin            0.805518
# dtype: float64

# %%
auto.mean()
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# origin             1.576531
# dtype: float64

# %%
auto_sub = pd.concat([auto[0:10],auto[85:]],axis=0)

# %%
auto_sub
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1    18.0          8         307.0         130    3504          12.0    70
# 2    15.0          8         350.0         165    3693          11.5    70
# 3    18.0          8         318.0         150    3436          11.0    70
# 4    16.0          8         304.0         150    3433          12.0    70
# 5    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0          86    2790          15.6    82
# 394  44.0          4          97.0          52    2130          24.6    82
# 395  32.0          4         135.0          84    2295          11.6    82
# 396  28.0          4         120.0          79    2625          18.6    82
# 397  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
auto_sub.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  317.000000  317.000000    317.000000  317.000000   317.000000
# mean    24.374763    5.381703    187.880126  101.003155  2938.854890
# std      7.872565    1.658135    100.169973   36.003208   811.640668
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    101.000000   75.000000  2215.000000
# 50%     23.900000    4.000000    146.000000   90.000000  2795.000000
# 75%     30.500000    6.000000    250.000000  115.000000  3520.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    317.000000  317.000000  317.000000
# mean      15.704101   77.123028    1.599369
# std        2.719913    3.127158    0.819308
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
# %matplotlib inline

# %%
sns.pairplot(auto)

# %%
#predict mpg with cyl disp hp wt year orig

# %%
a = df.describe()

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
a.loc[['mean','std']]
# Out:
#          Apps   Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# mean 3,001.64 2,018.80  779.97      27.56      55.80     3,699.91
# std  3,870.20 2,451.11  929.18      17.64      19.80     4,850.42
#
#       P.Undergrad  Outstate  Room.Board  Books  Personal   PhD  Terminal  \
# mean       855.30 10,440.67    4,357.53 549.38  1,340.64 72.66     79.70
# std      1,522.43  4,023.02    1,096.70 165.11    677.07 16.33     14.72
#
#       S.F.Ratio  perc.alumni   Expend  Grad.Rate
# mean      14.09        22.74 9,660.17      65.46
# std        3.96        12.39 5,221.77      17.18

# %%
df = pd.read_csv('hwdata\Boston.csv',index_col='Unnamed: 0')

# %%
len(df.columns)
# Out:
# 14

# %%
len(df)
# Out:
# 506

# %%
df.head(4)
# Out:
#    crim    zn  indus  chas  nox   rm   age  dis  rad  tax  ptratio  black  \
# 1  0.01 18.00   2.31     0 0.54 6.58 65.20 4.09    1  296    15.30 396.90
# 2  0.03  0.00   7.07     0 0.47 6.42 78.90 4.97    2  242    17.80 396.90
# 3  0.03  0.00   7.07     0 0.47 7.18 61.10 4.97    2  242    17.80 392.83
# 4  0.03  0.00   2.18     0 0.46 7.00 45.80 6.06    3  222    18.70 394.63
#
#    lstat  medv
# 1   4.98 24.00
# 2   9.14 21.60
# 3   4.03 34.70
# 4   2.94 33.40

# %%
sns.pairplot(data=df,height=1,aspect=1)

# %%
df.describe()
# Out:
#         crim     zn  indus   chas    nox     rm    age    dis    rad    tax  \
# count 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00
# mean    3.61  11.36  11.14   0.07   0.55   6.28  68.57   3.80   9.55 408.24
# std     8.60  23.32   6.86   0.25   0.12   0.70  28.15   2.11   8.71 168.54
# min     0.01   0.00   0.46   0.00   0.39   3.56   2.90   1.13   1.00 187.00
# 25%     0.08   0.00   5.19   0.00   0.45   5.89  45.02   2.10   4.00 279.00
# 50%     0.26   0.00   9.69   0.00   0.54   6.21  77.50   3.21   5.00 330.00
# 75%     3.68  12.50  18.10   0.00   0.62   6.62  94.07   5.19  24.00 666.00
# max    88.98 100.00  27.74   1.00   0.87   8.78 100.00  12.13  24.00 711.00
#
#        ptratio  black  lstat   medv
# count   506.00 506.00 506.00 506.00
# mean     18.46 356.67  12.65  22.53
# std       2.16  91.29   7.14   9.20
# min      12.60   0.32   1.73   5.00
# 25%      17.40 375.38   6.95  17.02
# 50%      19.05 391.44  11.36  21.20
# ...

# %%
df.crim.plot.hist()

# %%
df.crim.plot.box()

# %%
df
# Out:
#      crim    zn  indus  chas  nox   rm   age  dis  rad  tax  ptratio  black  \
# 1    0.01 18.00   2.31     0 0.54 6.58 65.20 4.09    1  296    15.30 396.90
# 2    0.03  0.00   7.07     0 0.47 6.42 78.90 4.97    2  242    17.80 396.90
# 3    0.03  0.00   7.07     0 0.47 7.18 61.10 4.97    2  242    17.80 392.83
# 4    0.03  0.00   2.18     0 0.46 7.00 45.80 6.06    3  222    18.70 394.63
# 5    0.07  0.00   2.18     0 0.46 7.15 54.20 6.06    3  222    18.70 396.90
# ..    ...   ...    ...   ...  ...  ...   ...  ...  ...  ...      ...    ...
# 502  0.06  0.00  11.93     0 0.57 6.59 69.10 2.48    1  273    21.00 391.99
# 503  0.05  0.00  11.93     0 0.57 6.12 76.70 2.29    1  273    21.00 396.90
# 504  0.06  0.00  11.93     0 0.57 6.98 91.00 2.17    1  273    21.00 396.90
# 505  0.11  0.00  11.93     0 0.57 6.79 89.30 2.39    1  273    21.00 393.45
# 506  0.05  0.00  11.93     0 0.57 6.03 80.80 2.50    1  273    21.00 396.90
#
#      lstat  medv
# 1     4.98 24.00
# 2     9.14 21.60
# ...

# %%
df[df['crim']>30]
# Out:
#      crim   zn  indus  chas  nox   rm    age  dis  rad  tax  ptratio  black  \
# 381 88.98 0.00  18.10     0 0.67 6.97  91.90 1.42   24  666    20.20 396.90
# 399 38.35 0.00  18.10     0 0.69 5.45 100.00 1.49   24  666    20.20 396.90
# 405 41.53 0.00  18.10     0 0.69 5.53  85.40 1.61   24  666    20.20 329.46
# 406 67.92 0.00  18.10     0 0.69 5.68 100.00 1.43   24  666    20.20 384.97
# 411 51.14 0.00  18.10     0 0.60 5.76 100.00 1.41   24  666    20.20   2.60
# 415 45.75 0.00  18.10     0 0.69 4.52 100.00 1.66   24  666    20.20  88.27
# 419 73.53 0.00  18.10     0 0.68 5.96 100.00 1.80   24  666    20.20  16.45
# 428 37.66 0.00  18.10     0 0.68 6.20  78.70 1.86   24  666    20.20  18.82
#
#      lstat  medv
# 381  17.21 10.40
# 399  30.59  5.00
# 405  27.38  8.50
# 406  22.98  5.00
# 411  10.11 15.00
# 415  36.98  7.00
# 419  20.62  8.80
# 428  14.52 10.90

# %%
len(df[df['chas']==1])
# Out:
# 35

# %%
df['chas'].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
df['ptratio'].mean()
# Out:
# 18.455533596837945

# %%
df['ptratio'].median()
# Out:
# 19.05

# %%
df.plot.scatter(x='rm',y='medv');
